# %%
print("welcome")
# Out:
# welcome

# %%
a=input()
print(a)

# %%
a=input()
print(a)

# %%
a=int(input())
print(a)

# %%
a=float(input())
print("% .2f"%a)

# %%
a=int(input())
print(hex(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=int(input())
#       2 print(hex(a))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a=int(input())
print(oct(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a=int(input())
#       2 print(oct(a))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
oct=int(input())
print(int(oct,8))

# %%
a=input()
print(odr(a))

# %%
a=56
b=78
print(a , b)

# %%
a=89
print(chr(a))
