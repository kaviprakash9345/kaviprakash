# %%
print("welcome")
# Out:
# welcome

# %%
a=input()
print(a)
# Out:
# welcome

# %%
a=input()
print(a)
# Out:
# welcome

# %%
a=int(input())
print(a)
# Out:
# 67

# %%
a=float(input())
print("% .2f"%a)
# Out:
#  89.79

# %%
a=int(input())
print(hex(a))
# Out:
# 0x4e

# %%
a=int(input())
print(oct(a))
# Out:
# 0o131

# %%
oct=input()
print(int(oct,8))
# Out:
# 89

# %%
a=input()
print(ord(a))
# Out:
# 117

# %%
a=56
b=78
print(a , b)
# Out:
# 56 78

# %%
a=89
print(chr(a))
# Out:
# Y

# %%
a=67
b=89
print(a,"\n",b)
# Out:
# 67
#  89

# %%
date=int(input())
month=input()
year=int(input())
print(date,"/",month,"/",year)
# Out:
# 29 / sept / 2005

# %%
a=67
print("%+d"%a)
# Out:
# +67

# %%
roll="L126"
name="kaviprakash"
print("roll no:",roll,"name:",name)
# Out:
# roll no: L126 name: kaviprakash

# %%
tamil=67
eng=89
sci=90
maths=78
social=100
print("tamil :",tamil,"\n","english:",eng,"\n","science:",sci,"\n","maths:",maths,"\n","social:",social)
# Out:
# tamil : 67
#  english: 89
#  science: 90
#  maths: 78
#  social: 100

# %%
a=input()
print(a)
# Out:
# A+

# %%
from datetime import datetime

current_time = datetime.now().strftime("%H:%M:%S")
print(current_time)
# Out:
# 11:39:52

# %%
word1 = "kavi"
word2 = "prakash"
print(f'"{word1}" "{word2}"')
# Out:
# "kavi" "prakash"

# %%
ch = 'A'
print(f"'{ch}'")
# Out:
# 'A'
