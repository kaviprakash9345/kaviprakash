# %%
a=int(input())
b=int(input())
print(a+b)
# Out:
# 101

# %%
a=int(input())
b=int(input())
print(a-b)
# Out:
# -33

# %%
a=int(input())
b=int(input())
print(a*b)
# Out:
# 536

# %%
a=int(input())
b=int(input())
print(a%b)
# Out:
# 3

# %%
a=int(input())
b=int(input())
print(a/b)
# Out:
# 1.0

# %%
a=int(input())
b=int(input())
temp=a
a=b
b=temp
print(a,b)
# Out:
# 10 5

# %%
a=int(input())
print(a%10)
# Out:
# 9

# %%
a,b=map(int,input().split())
a,b=b,a
print(a,b)
# Out:
# 6 5

# %%
n = int(input())

first = n // 100
last = n % 10

print(first + last)
# Out:
# 16

# %%
n = int(input())

print(abs(n))
# Out:
# 878

# %%
n = int(input())

print(n*n)
# Out:
# 9

# %%
n = int(input())

print(n*n*n)
# Out:
# 8

# %%
n = int(input())

if n >= 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Positive

# %%
a = int(input())
b = int(input())
c = int(input())

print(max(a, b, c))
# Out:
# 99

# %%
marks = int(input())

if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail
