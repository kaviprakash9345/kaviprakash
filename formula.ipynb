# %%
l = float(input())
b = float(input())

area = l * b

print(area)
# Out:
# 340.0

# %%
a = float(input())

print(a * a)
# Out:
# 100.0

# %%
b = float(input())
h = float(input())

area = 0.5 * b * h

print(area)
# Out:
# 770.5

# %%
r = float(input())

area = 3.14*r*r

print(area)
# Out:
# 14095.46

# %%
f = float(input())

c = (f-32)*5/9

print(c)
# Out:
# 5.555555555555555

# %%
c = float(input())

f = (9/5)*c+32

print(f)
# Out:
# 132.8

# %%
a = float(input())

print(4*a)
# Out:
# 180.0

# %%
l = float(input())
b = float(input())

p = 2*(l+b)

print(p)
# Out:
# 180.0

# %%
a = float(input())
b = float(input())
c = float(input())

print(a + b + c)
# Out:
# 69.0

# %%
r = float(input())

c = 2*3.14*r

print(c)
# Out:
# 2166.6
